# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidney-130/learning-pytorch/blob/main/Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

# %%
tensor_A = torch.tensor([1,2,3])
tensor_A
# Out:
# tensor([1, 2, 3])
